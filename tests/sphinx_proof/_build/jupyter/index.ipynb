# %% [markdown]
# # sphinx-proof Test Suite
#
# This test suite validates sphinx-proof directive support in sphinx-tojupyter.
#
# - [Basic Directives Test](test_basic_directives.ipynb)
#   - [Theorem](test_basic_directives.ipynb#theorem)
#   - [Axiom](test_basic_directives.ipynb#axiom)
#   - [Lemma](test_basic_directives.ipynb#lemma)
#   - [Definition](test_basic_directives.ipynb#definition)
#   - [Remark](test_basic_directives.ipynb#remark)
#   - [Conjecture](test_basic_directives.ipynb#conjecture)
#   - [Corollary](test_basic_directives.ipynb#corollary)
#   - [Algorithm](test_basic_directives.ipynb#algorithm)
#   - [Criterion](test_basic_directives.ipynb#criterion)
#   - [Example](test_basic_directives.ipynb#example)
#   - [Property](test_basic_directives.ipynb#property)
#   - [Observation](test_basic_directives.ipynb#observation)
#   - [Proposition](test_basic_directives.ipynb#proposition)
#   - [Assumption](test_basic_directives.ipynb#assumption)
#   - [Notation](test_basic_directives.ipynb#notation)
# - [Numbered Directives with Titles](test_numbered_directives.ipynb)
#   - [Named Theorem](test_numbered_directives.ipynb#named-theorem)
#   - [Named Definition](test_numbered_directives.ipynb#named-definition)
#   - [Named Lemma](test_numbered_directives.ipynb#named-lemma)
#   - [Unnumbered Example](test_numbered_directives.ipynb#unnumbered-example)
#   - [Another Numbered Theorem](test_numbered_directives.ipynb#another-numbered-theorem)
#   - [Cross-referencing](test_numbered_directives.ipynb#cross-referencing)
# - [Proofs](test_proofs.ipynb)
#   - [Theorem with Proof](test_proofs.ipynb#theorem-with-proof)
#   - [Simple Proof](test_proofs.ipynb#simple-proof)
#   - [Proof with Class Name](test_proofs.ipynb#proof-with-class-name)
