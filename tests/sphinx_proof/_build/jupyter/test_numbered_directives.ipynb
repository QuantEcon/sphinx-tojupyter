# %% [markdown]
# # Numbered Directives with Titles
#
# This document tests numbered directives with titles.

# %% [markdown]
# ## Named Theorem

# %% [markdown]
# **Theorem 2** (Pythagorean Theorem)
#
# In a right triangle, the square of the hypotenuse equals the sum of squares of the other two sides:
#
# $$
# a^2 + b^2 = c^2
# $$

# %% [markdown]
# ## Named Definition

# %% [markdown]
# **Definition 2** (Limit of a Function)
#
# We say that $ \lim_{x \to a} f(x) = L $ if for every $ \epsilon > 0 $, there exists $ \delta > 0 $ such that $ 0 < |x - a| < \delta $ implies $ |f(x) - L| < \epsilon $.

# %% [markdown]
# ## Named Lemma

# %% [markdown]
# **Lemma 2** (Fundamental Lemma)
#
# If $ f $ is continuous on $ [a,b] $ and differentiable on $ (a,b) $, then there exists $ c \in (a,b) $ such that:
#
# $$
# f'(c) = \frac{f(b) - f(a)}{b - a}
# $$

# %% [markdown]
# ## Unnumbered Example
#
# Some directives can be unnumbered using the `:nonumber:` option:

# %% [markdown]
# **Example**
#
# This example has no number assigned to it.
#
# $$
# \int_0^\infty e^{-x} dx = 1
# $$

# %% [markdown]
# ## Another Numbered Theorem

# %% [markdown]
# **Theorem 3** (Mean Value Theorem)
#
# Let $ f $ be continuous on $ [a,b] $ and differentiable on $ (a,b) $. Then there exists $ c \in (a,b) $ such that:
#
# $$
# f'(c) = \frac{f(b) - f(a)}{b - a}
# $$

# %% [markdown]
# ## Cross-referencing
#
# We can reference [Theorem 2](#pythagoras) and [Definition 2](#limit-definition) in our text.
#
# The [Lemma 2](#fundamental-lemma) is used to prove [Theorem 3](#mvt).
